# %% [markdown]
# # Train các model (Trước khi hypertuned)

# %%
# --- Evaluating submission_knn.csv ---
#   Loaded model submission. Shape: (3600, 2)
#   Model submission columns: ['Id', 'target']
#   Could not calculate ROC AUC: axis 1 is out of bounds for array of dimension 1. It might require probability scores or specific label encoding.
#   Accuracy (Classification): 0.4919
#   F1 Score (Classification, macro): 0.4482
#   ROC AUC (Classification, macro, ovr): nan

# --- Evaluating submission_naivebayes.csv ---
#   Loaded model submission. Shape: (3600, 2)
#   Model submission columns: ['Id', 'target']
#   Could not calculate ROC AUC: axis 1 is out of bounds for array of dimension 1. It might require probability scores or specific label encoding.
#   Accuracy (Classification): 0.4808
#   F1 Score (Classification, macro): 0.4226
#   ROC AUC (Classification, macro, ovr): nan

# --- Evaluating submission_randomforest.csv ---
#   Loaded model submission. Shape: (3600, 2)
#   Model submission columns: ['Id', 'target']
#   Could not calculate ROC AUC: axis 1 is out of bounds for array of dimension 1. It might require probability scores or specific label encoding.
# ...
#   F1 Score (Classification, macro): 0.6652
#   ROC AUC (Classification, macro, ovr): nan

# %% [markdown]
# # Các tham số tốt nhất:

# %%
# --- Model: RandomForest ---
# Best Parameters: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'max_depth': None}
# Best CV F1 Macro Mean: 0.4184
# Validation Accuracy: 0.4552
# Validation F1 Macro: 0.4225
# Validation ROC AUC Macro: 0.8320

# --- Model: XGB ---
# Best Parameters: {'subsample': 0.8, 'n_estimators': 200, 'max_depth': 3, 'learning_rate': 0.2, 'colsample_bytree': 0.8}
# Best CV F1 Macro Mean: 0.4580
# Validation Accuracy: 0.4847
# Validation F1 Macro: 0.4608
# Validation ROC AUC Macro: 0.8718

# --- Model: KNN ---
# Best Parameters: {'metric': 'manhattan', 'n_neighbors': 11, 'weights': 'uniform'}
# Best CV F1 Macro Mean: 0.3912
# Validation Accuracy: 0.4160
# Validation F1 Macro: 0.3895
# Validation ROC AUC Macro: 0.7890

# %% [markdown]
# # Sau khi hypertune:

# %%
# --- Evaluating submission_knn.csv ---
#   Loaded model submission. Shape: (3600, 2)
#   Model submission columns: ['Id', 'target']
#   Could not calculate ROC AUC: axis 1 is out of bounds for array of dimension 1. It might require probability scores or specific label encoding.
#   Accuracy (Classification): 0.4919
#   F1 Score (Classification, macro): 0.4482
#   ROC AUC (Classification, macro, ovr): nan

# --- Evaluating submission_naivebayes.csv ---
#   Loaded model submission. Shape: (3600, 2)
#   Model submission columns: ['Id', 'target']
#   Could not calculate ROC AUC: axis 1 is out of bounds for array of dimension 1. It might require probability scores or specific label encoding.
#   Accuracy (Classification): 0.4808
#   F1 Score (Classification, macro): 0.4226
#   ROC AUC (Classification, macro, ovr): nan

# --- Evaluating submission_randomforest.csv ---
#   Loaded model submission. Shape: (3600, 2)
#   Model submission columns: ['Id', 'target']
#   Could not calculate ROC AUC: axis 1 is out of bounds for array of dimension 1. It might require probability scores or specific label encoding.
# ...
#   F1 Score (Classification, macro): 0.6652
#   ROC AUC (Classification, macro, ovr): nan
